# %% [markdown]
# ROSATO Alessio
# # Homework Section 1

# %% [markdown]
# ### Exercise 2 (p.52, Chap.2)

# %% [markdown]
# 2a)

# %% [markdown]
# This is a REGRESSION scenario where we are most interested in INFERENCE. In particular, inferring which factors affect CEO salary given the firm's profit, number of employees, industry, and the CEO salary.
#
# n - 500 firms in the US
#
# p - profit, number of employees, and industry

# %% [markdown]
# 2b)

# %% [markdown]
# This is a CLASSIFICATION scenario where we are most interested in PREDICTION. In particular, predicting a new product's success or failure given the success or failure, the price, the marketing budget, the competition price, and ten other variables of 20 similar products.
#
# n - 20 similar products previously launched
#
# p - price, marketing budget, competition price, and ten other variables

# %% [markdown]
# 2c)

# %% [markdown]
# This is a REGRESSION scenario where we are most interested in PREDICTION. In particular, predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets.
#
# n - weekly data of all 2012 (52 weeks)
#
# p - the % change in US market, the % change in British market, and the % change in German market

# %% [markdown]
# ### Exercise 10 (p.56, Chap.2)

# %% [markdown]
# 10a)

# %%
library(MASS)
# Out:
# Warning message:
# "package 'MASS' was built under R version 3.6.3"

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
?Boston

# %% [markdown]
# "The Boston data frame has 506 rows and 14 columns."

# %% [markdown]
# 10b)

# %%
pairs(Boston)
# Out:
# plot without title

# %% [markdown]
# 10c)

# %%
#The higher the proportion of owner-occupied units built prior to 1940, the higher the crime rate per capita
plot(Boston$age, Boston$crim)

#The less the distance form work, the higher the crime rate per capita
plot(Boston$dis, Boston$crim)

#The higher the tax rate, the higher the crime rate per capita
plot(Boston$tax, Boston$crim)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# 10d)

# %% [markdown]
# 10e)

# %%
dim(subset(Boston, chas == 1))
# Out:
# [1] 35 14

# %% [markdown]
# 35 suburbs

# %% [markdown]
# 10f)

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# 10g)

# %%
t(subset(Boston, medv == min(Boston$medv)))
# Out:
#         399      406
# crim     38.3518  67.9208
# zn        0.0000   0.0000
# indus    18.1000  18.1000
# chas      0.0000   0.0000
# nox       0.6930   0.6930
# rm        5.4530   5.6830
# age     100.0000 100.0000
# dis       1.4896   1.4254
# rad      24.0000  24.0000
# tax     666.0000 666.0000
# ptratio  20.2000  20.2000
# black   396.9000 384.9700
# lstat    30.5900  22.9800
# medv      5.0000   5.0000

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# 10h)

# %%
dim(subset(Boston, rm > 7)) #64 suburbs
# Out:
# [1] 64 14

# %%
dim(subset(Boston, rm > 8)) #13 suburbs
# Out:
# [1] 13 14

# %%
summary(subset(Boston, rm > 8))
# Out:
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
#       rad              tax           ptratio          black
# ...

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# ### Exercise 3 (p.120, Chap.3)

# %% [markdown]
# Y = 50 + 20(GPA) + 0.07(IQ) + 35(gender) + 0.01(GPA * IQ) - 10 (GPA * gender)

# %% [markdown]
# 3a)

# %% [markdown]
# Option 'iii' is correct because in roder to earn more than females (Gender = 1), males need a GPA that is high enough to compensate (given that for males 35(gender = 0) and -10(GPA * Gender = 0) are both equal to 0)

# %% [markdown]
# 3b)

# %%
Y <- 50 + 20 * 4 + 0.07 * 110 + 35 + 0.01 * 4 * 110 - 10 * 4
Y
# Out:
# [1] 137.1

# %% [markdown]
# 3c)

# %% [markdown]
# FALSE.
#
# Before concluding whether a regression coefficient is statistical significant or not, One should always conduct a hypothesis testing and check the relative p-value.

# %% [markdown]
# ### Exercise 10 (p.123, Chap.3)

# %% [markdown]
# 10a)

# %%
library(ISLR)

# %%
head(Carseats)
# Out:
#   Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1  9.50 138        73    11          276        120   Bad       42  17
# 2 11.22 111        48    16          260         83   Good      65  10
# 3 10.06 113        35    10          269         80   Medium    59  12
# 4  7.40 117       100     4          466         97   Medium    55  14
# 5  4.15 141        64     3          340        128   Bad       38  13
# 6 10.81 124       113    13          501         72   Bad       78  16
#   Urban US
# 1 Yes   Yes
# 2 Yes   Yes
# 3 Yes   Yes
# 4 Yes   Yes
# 5 Yes   No
# 6 No    Yes

# %%
lm.fit = lm(Carseats$Sales~Carseats$Price+Carseats$Urban+Carseats$US)
summary(lm.fit)
# Out:
# Call:
# lm(formula = Carseats$Sales ~ Carseats$Price + Carseats$Urban +
#     Carseats$US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       13.043469   0.651012  20.036  < 2e-16 ***
# Carseats$Price    -0.054459   0.005242 -10.389  < 2e-16 ***
# Carseats$UrbanYes -0.021916   0.271650  -0.081    0.936
# Carseats$USYes     1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# 10b)

# %% [markdown]
# 10c)

# %% [markdown]
# Sales = 13.04 - 0.05 Price - 0.02 UrbanYes + 1.20 USYes

# %% [markdown]
# 10d)

# %% [markdown]
# Only for Price and USYes we can reject the null hypothesis H0: Bj = 0, based on the p-values, F-statistic, and p-value of the F-statistic.

# %% [markdown]
# 10e)

# %%
lm.fit_smaller = lm(Carseats$Sales ~ Carseats$Price + Carseats$US)
summary(lm.fit_smaller)
# Out:
# Call:
# lm(formula = Carseats$Sales ~ Carseats$Price + Carseats$US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    13.03079    0.63098  20.652  < 2e-16 ***
# Carseats$Price -0.05448    0.00523 -10.416  < 2e-16 ***
# Carseats$USYes  1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# 10f)

# %% [markdown]
# The two models hve the same R2, with the second having a slightly smaller RSE. Therefore, they both fit the data similarly, but the second one is slightly better.

# %% [markdown]
# 10g)

# %%
confint(lm.fit_smaller, level = 0.95)
# Out:
#                2.5 %       97.5 %
# (Intercept)    11.79032020 14.27126531
# Carseats$Price -0.06475984 -0.04419543
# Carseats$USYes  0.69151957  1.70776632

# %% [markdown]
# 10h)

# %%
plot(predict(lm.fit_smaller), rstudent(lm.fit_smaller))
# Out:
# plot without title

# %% [markdown]
# All the residuals are bounded in between -3 and 3, so there is no evidence of outliers.

# %% [markdown]
# ### Exercise 15 (p.126, Chap.3).

# %% [markdown]
# 15a)

# %%
lm.zn = lm(Boston$crim~Boston$zn)
summary(lm.zn)

#Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$zn)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -4.429 -4.222 -2.620  1.250 84.523
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.45369    0.41722  10.675  < 2e-16 ***
# Boston$zn   -0.07393    0.01609  -4.594 5.51e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.435 on 504 degrees of freedom
# Multiple R-squared:  0.04019,	Adjusted R-squared:  0.03828
# F-statistic:  21.1 on 1 and 504 DF,  p-value: 5.506e-06

# %%
lm.indus = lm(Boston$crim~Boston$indus)
summary(lm.indus)

#Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$indus)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.972  -2.698  -0.736   0.712  81.813
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -2.06374    0.66723  -3.093  0.00209 **
# Boston$indus  0.50978    0.05102   9.991  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.866 on 504 degrees of freedom
# Multiple R-squared:  0.1653,	Adjusted R-squared:  0.1637
# F-statistic: 99.82 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.chas = lm(Boston$crim~Boston$chas) 
summary(lm.chas) 

# Not statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$chas)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.738 -3.661 -3.435  0.018 85.232
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.7444     0.3961   9.453   <2e-16 ***
# Boston$chas  -1.8928     1.5061  -1.257    0.209
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.597 on 504 degrees of freedom
# Multiple R-squared:  0.003124,	Adjusted R-squared:  0.001146
# F-statistic: 1.579 on 1 and 504 DF,  p-value: 0.2094

# %%
lm.nox = lm(Boston$crim~Boston$nox) 
summary(lm.nox) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$nox)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.371  -2.738  -0.974   0.559  81.728
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -13.720      1.699  -8.073 5.08e-15 ***
# Boston$nox    31.249      2.999  10.419  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.81 on 504 degrees of freedom
# Multiple R-squared:  0.1772,	Adjusted R-squared:  0.1756
# F-statistic: 108.6 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.rm = lm(Boston$crim~Boston$rm) 
summary(lm.rm) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$rm)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -6.604 -3.952 -2.654  0.989 87.197
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   20.482      3.365   6.088 2.27e-09 ***
# Boston$rm     -2.684      0.532  -5.045 6.35e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.401 on 504 degrees of freedom
# Multiple R-squared:  0.04807,	Adjusted R-squared:  0.04618
# F-statistic: 25.45 on 1 and 504 DF,  p-value: 6.347e-07

# %%
lm.age = lm(Boston$crim~Boston$age) 
summary(lm.age) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$age)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -6.789 -4.257 -1.230  1.527 82.849
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -3.77791    0.94398  -4.002 7.22e-05 ***
# Boston$age   0.10779    0.01274   8.463 2.85e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.057 on 504 degrees of freedom
# Multiple R-squared:  0.1244,	Adjusted R-squared:  0.1227
# F-statistic: 71.62 on 1 and 504 DF,  p-value: 2.855e-16

# %%
lm.dis = lm(Boston$crim~Boston$dis) 
summary(lm.dis) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$dis)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -6.708 -4.134 -1.527  1.516 81.674
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   9.4993     0.7304  13.006   <2e-16 ***
# Boston$dis   -1.5509     0.1683  -9.213   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.965 on 504 degrees of freedom
# Multiple R-squared:  0.1441,	Adjusted R-squared:  0.1425
# F-statistic: 84.89 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.rad = lm(Boston$crim~Boston$rad) 
summary(lm.rad) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$rad)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.164  -1.381  -0.141   0.660  76.433
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.28716    0.44348  -5.157 3.61e-07 ***
# Boston$rad   0.61791    0.03433  17.998  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.718 on 504 degrees of freedom
# Multiple R-squared:  0.3913,	Adjusted R-squared:   0.39
# F-statistic: 323.9 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.tax = lm(Boston$crim~Boston$tax) 
summary(lm.tax) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$tax)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.513  -2.738  -0.194   1.065  77.696
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -8.528369   0.815809  -10.45   <2e-16 ***
# Boston$tax   0.029742   0.001847   16.10   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.997 on 504 degrees of freedom
# Multiple R-squared:  0.3396,	Adjusted R-squared:  0.3383
# F-statistic: 259.2 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.ptratio = lm(Boston$crim~Boston$ptratio) 
summary(lm.ptratio) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$ptratio)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.654 -3.985 -1.912  1.825 83.353
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -17.6469     3.1473  -5.607 3.40e-08 ***
# Boston$ptratio   1.1520     0.1694   6.801 2.94e-11 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.24 on 504 degrees of freedom
# Multiple R-squared:  0.08407,	Adjusted R-squared:  0.08225
# F-statistic: 46.26 on 1 and 504 DF,  p-value: 2.943e-11

# %%
lm.black = lm(Boston$crim~Boston$black) 
summary(lm.black) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$black)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -13.756  -2.299  -2.095  -1.296  86.822
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  16.553529   1.425903  11.609   <2e-16 ***
# Boston$black -0.036280   0.003873  -9.367   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.946 on 504 degrees of freedom
# Multiple R-squared:  0.1483,	Adjusted R-squared:  0.1466
# F-statistic: 87.74 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.lstat = lm(Boston$crim~Boston$lstat) 
summary(lm.lstat) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$lstat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -13.925  -2.822  -0.664   1.079  82.862
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -3.33054    0.69376  -4.801 2.09e-06 ***
# Boston$lstat  0.54880    0.04776  11.491  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.664 on 504 degrees of freedom
# Multiple R-squared:  0.2076,	Adjusted R-squared:  0.206
# F-statistic:   132 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
lm.medv = lm(Boston$crim~Boston$medv) 
summary(lm.medv) 

# Statistically significant
# Out:
# Call:
# lm(formula = Boston$crim ~ Boston$medv)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.071 -4.022 -2.343  1.298 80.957
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 11.79654    0.93419   12.63   <2e-16 ***
# Boston$medv -0.36316    0.03839   -9.46   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.934 on 504 degrees of freedom
# Multiple R-squared:  0.1508,	Adjusted R-squared:  0.1491
# F-statistic: 89.49 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
plot(lm.chas) #Only chas has no statistically significant correlation with with the dependent variable
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# 15b)

# %%
lm.all_predictors = lm(crim~., data=Boston)
summary(lm.all_predictors)
# Out:
# Call:
# lm(formula = crim ~ ., data = Boston)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.924 -2.120 -0.353  1.019 75.051
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  17.033228   7.234903   2.354 0.018949 *
# zn            0.044855   0.018734   2.394 0.017025 *
# indus        -0.063855   0.083407  -0.766 0.444294
# chas         -0.749134   1.180147  -0.635 0.525867
# nox         -10.313535   5.275536  -1.955 0.051152 .
# rm            0.430131   0.612830   0.702 0.483089
# age           0.001452   0.017925   0.081 0.935488
# dis          -0.987176   0.281817  -3.503 0.000502 ***
# rad           0.588209   0.088049   6.680 6.46e-11 ***
# tax          -0.003780   0.005156  -0.733 0.463793
# ptratio      -0.271081   0.186450  -1.454 0.146611
# black        -0.007538   0.003673  -2.052 0.040702 *
# lstat         0.126211   0.075725   1.667 0.096208 .
# medv         -0.198887   0.060516  -3.287 0.001087 **
# ---
# ...

# %% [markdown]
# Only for the predictors zn, dis, rad, black, and medv.
